# %%
import pandas as pd
import numpy as np

# %%
train_fuel = pd.read_csv('train1_f.csv')
test_fuel = pd.read_csv('test1_f.csv')

# %%
df_resampled = train_fuel.groupby(lambda x:x//5).mean()

# %%
df_resampled.head()
# Out:
#     ACID  Flight_instance_ID    Year  Month   Day  Hour  Minute  Second  \
# 0  676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0     2.0
# 1  676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0     7.0
# 2  676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    12.0
# 3  676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    17.0
# 4  676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    22.0
#
#          ABRK     ELEV_1  ...      BPGR_2     BPYR_1  BPYR_2  CALT   CASS  \
# 0  119.983559  19.052563  ...   28.320384  50.781378     0.0   0.0  135.0
# 1  119.983559  19.044380  ...   26.367254  51.757944     0.0   0.0  135.0
# 2  119.983559  19.907708  ...   26.367254  49.804813     0.0   0.0  135.0
# 3  119.983559  20.181846  ...   26.367254  51.757944     0.0   0.0  135.0
# 4  119.983559  20.181846  ...   28.320384  52.734509     0.0   0.0  135.0
#
#         CRSS  DFGS     DWPT  EAI    FF
# 0 -29.091582   1.0  75024.0  0.0   0.0
# ...

# %%
df_resampled
# Out:
#        ACID  Flight_instance_ID    Year  Month   Day  Hour  Minute  Second  \
# 0     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0     2.0
# 1     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0     7.0
# 2     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    12.0
# 3     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    17.0
# 4     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    22.0
# 5     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    27.0
# 6     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    32.0
# 7     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    37.0
# 8     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    42.0
# 9     676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    47.0
# 10    676.0        6.762004e+14  2004.0    5.0  11.0  20.0     6.0    52.0
# ...

# %%
train_fuel
# Out:
#       ACID  Flight_instance_ID  Year  Month  Day  Hour  Minute  Second  \
# 0      676     676200405112006  2004      5   11    20       6       0
# 1      676     676200405112006  2004      5   11    20       6       1
# 2      676     676200405112006  2004      5   11    20       6       2
# 3      676     676200405112006  2004      5   11    20       6       3
# 4      676     676200405112006  2004      5   11    20       6       4
# 5      676     676200405112006  2004      5   11    20       6       5
# 6      676     676200405112006  2004      5   11    20       6       6
# 7      676     676200405112006  2004      5   11    20       6       7
# 8      676     676200405112006  2004      5   11    20       6       8
# 9      676     676200405112006  2004      5   11    20       6       9
# 10     676     676200405112006  2004      5   11    20       6      10
# 11     676     676200405112006  2004      5   11    20       6      11
# ...

# %%
my_df = pd.DataFrame(df_resampled)

# %%
my_df.to_csv('train_filtered.csv', index=False, header=False)

# %%
df_resampled1 = test_fuel.groupby(lambda x:x//5).mean()

# %%
my_df1 = pd.DataFrame(df_resampled1)

# %%
my_df.to_csv('test_filtered.csv', index=False, header=False)

# %%
df_resampled1
# Out:
#       ACID  Flight_instance_ID    Year  Month   Day  Hour  Minute  Second  \
# 0    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    20.0
# 1    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    25.0
# 2    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    30.0
# 3    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    35.0
# 4    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    40.0
# 5    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    45.0
# 6    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    50.0
# 7    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.0    55.0
# 8    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    18.6    24.0
# 9    676.0        6.762004e+14  2004.0    5.0  11.0  15.0    19.0     5.0
# 10   676.0        6.762004e+14  2004.0    5.0  11.0  15.0    19.0    10.0
# 11   676.0        6.762004e+14  2004.0    5.0  11.0  15.0    19.0    15.0
# ...

# %%
test_fuel
# Out:
#       ACID  Flight_instance_ID  Year  Month  Day  Hour  Minute  Second  \
# 0      676     676200405111519  2004      5   11    15      18      18
# 1      676     676200405111519  2004      5   11    15      18      19
# 2      676     676200405111519  2004      5   11    15      18      20
# 3      676     676200405111519  2004      5   11    15      18      21
# 4      676     676200405111519  2004      5   11    15      18      22
# 5      676     676200405111519  2004      5   11    15      18      23
# 6      676     676200405111519  2004      5   11    15      18      24
# 7      676     676200405111519  2004      5   11    15      18      25
# 8      676     676200405111519  2004      5   11    15      18      26
# 9      676     676200405111519  2004      5   11    15      18      27
# 10     676     676200405111519  2004      5   11    15      18      28
# 11     676     676200405111519  2004      5   11    15      18      29
# ...
